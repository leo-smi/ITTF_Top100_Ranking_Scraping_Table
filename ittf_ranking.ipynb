# %%
import pandas as pd

# %%
url = "https://www.ittf.com/rankings/"

# %%
df = pd.read_html(url)
df = df[0]
df
# Out:
#    Ranking  Previous               Name Assoc.  Ranking Pts.
# 0        1         1             XU Xin    CHN         15980
# 1        2         3       FAN Zhendong    CHN         15470
# 2        3         5            MA Long    CHN         14955
# 3        4         2        LIN Gaoyuan    CHN         14900
# 4        5         4  HARIMOTO Tomokazu    JPN         13345
# 5        6         7     CALDERANO Hugo    BRA         12540
# 6        7         9      FALCK Mattias    SWE         12340
# 7        8         8          BOLL Timo    GER         12325
# 8        9         6      LIANG Jingkun    CHN         12190
# 9       10        12          NIWA Koki    JPN         11200

# %%
#df = df.to_dict()
#df
coeff = df["Ranking Pts."][5]/df["Ranking Pts."][0]
print(f"O coeficiente do Hugo Calderano é {coeff*100}%")
# Out:
# O coeficiente do Hugo Calderano é 78.47309136420526%
